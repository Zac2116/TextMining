# %%
import pandas as pd

# %%
data=pd.read_csv("~/Desktop/TextMining/data/loss.csv")
data
# Out:
#     step  Train Loss
# 0     99     0.34844
# 1    199     0.16376
# 2    299     0.13799
# 3    399     0.13834
# 4    499     0.16640
# 5    599     0.18470
# 6    699     0.11049
# 7    799     0.14795
# 8    899     0.14368
# 9    999     0.18024
# 10  1099     0.17780
# 11  1199     0.12233
# 12  1299     0.13998
# 13  1399     0.14335
# 14  1499     0.12819
# 15  1599     0.13402
# 16  1699     0.13459
# 17  1799     0.11681
# 18  1899     0.09997
# 19  1999     0.15086
# 20  2099     0.17250
# 21  2199     0.11380
# 22  2299     0.10970
# 23  2399     0.11496
# 24  2499     0.16441
# 25  2599     0.16500
# 26  2699     0.11046
# 27  2799     0.06854
# 28  2899     0.13204
# 29  2999     0.13951
# 30  3099     0.16282
# 31  3199     0.12421
# 32  3299     0.13949
# 33  3399     0.11989
# 34  3499     0.12586
# 35  3599     0.12857
# 36  3699     0.16198
# 37  3799     0.13870
# 38  3899     0.12978
# 39  3999     0.11287
# 40  4099     0.10948
# 41  4199     0.14639
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(data['step'],data['Train Loss'])
plt.ylabel('Training Loss')
plt.xlabel('step')
plt.style.use('ggplot')
